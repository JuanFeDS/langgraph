# %% [markdown]
# ### **📚 Librerías**

# %%
import sys
sys.path.append('../')

# %%
from src.agents.first_agents.simple_chat import agent

# %%
from IPython.display import Image, display

# %% [markdown]
# ### **🎨Visualización del grafo**

# %%
print(agent.get_graph().draw_ascii())
# Out:
#              +-----------+
#              | __start__ |
#              +-----------+
#                     *
#                     *
#                     *
#              +------------+
#              | check_info |
#              +------------+
#              ...         ...
#             .               .
#           ..                 ...
#   +----------+                  .
#   | ask_info |                  .
#   +----------+                  .
#         *                       .
#         *                       .
#         *                       .
# +--------------+                .
# | extract_info |             ...
# +--------------+            .
#              ***         ...
#                 *       .
#                  **   ..
#                +-------+
#                | greet |
#                +-------+
#                     *
#                     *
#                     *
#               +---------+
#               | __end__ |
#               +---------+

# %%
print(agent.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	check_info(check_info)
# 	ask_info(ask_info)
# 	extract_info(extract_info)
# 	greet(greet)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> check_info;
# 	ask_info --> extract_info;
# 	check_info -.-> ask_info;
# 	check_info -.-> greet;
# 	extract_info --> greet;
# 	greet --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %% [markdown]
# Esta última salida la podemos ver gráficamente en https://mermaid.live/.
#
# Copiamos el código desde ***graph TD***
